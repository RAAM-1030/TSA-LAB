# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

date_rng = pd.date_range(start='2020-01-01', end='2021-12-31', freq='D')

trend = np.linspace(0, 100, len(date_rng))
seasonality = 10 * np.sin(np.linspace(0, 3.14 * 2, len(date_rng)))
noise = np.random.normal(0, 2, len(date_rng))

data = trend + seasonality + noise

df = pd.DataFrame(data, columns=['value'], index=date_rng)

def plot_time_series(df):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['value'], label='Generated Time Series', color='blue')
    plt.title('Generated Time Series Data')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

def plot_boxplot(df):
    plt.figure(figsize=(8, 6))
    sns.boxplot(y=df['value'], color='lightblue')
    plt.title('Boxplot of Time Series Data')
    plt.ylabel('Value')
    plt.show()

def plot_histogram(df):
    plt.figure(figsize=(8, 6))
    plt.hist(df['value'], bins=30, color='skyblue', edgecolor='black')
    plt.title('Histogram of Time Series Data')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()

def plot_rolling_mean(df, window=30):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['value'], label='Original', color='blue', alpha=0.5)
    plt.plot(df.index, df['value'].rolling(window=window).mean(), label=f'Rolling Mean ({window} days)', color='red')
    plt.title('Rolling Mean of Time Series Data')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

plot_time_series(df)
plot_boxplot(df)
plot_histogram(df)
plot_rolling_mean(df)

print(df.head())
# Out:
#                value
# 2020-01-01  2.829927
# 2020-01-02  0.473105
# 2020-01-03 -0.067615
# 2020-01-04  2.717586
# 2020-01-05 -2.353060
